# %%
import tensorflow as tf
import numpy as np
import math

# %%
celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

# %%
capa = tf.keras.layers.Dense(units=1, input_shape=[1])
modelo = tf.keras.Sequential([capa])

# %%
modelo.compile(
    optimizer = tf.keras.optimizers.Adam(0.1),
    loss = 'mean_squared_error'
)

# %%
print('Entrenando...')
historial = modelo.fit(celsius, fahrenheit, epochs=700, verbose=False)
print('Modelo entrenado...')
# Out:
# Entrenando...
# Modelo entrenado...

# %%
import matplotlib.pyplot as plt
plt.xlabel('#Epoca')
plt.ylabel('Magnitud perdida')
plt.plot(historial.history['loss'])

# %%
print('Hagamos una prediccion...') 
celsius = input('Digite los grados Celsius: ')
resultado = modelo.predict([float(celsius)])
redondeo = math.ceil(resultado)
print(str(celsius) + ' grados Celsius es igual a ' + str(redondeo) + ' grados Fahrenheit')
# Out:
# Hagamos una prediccion...
# Digite los grados Celsius: 100
# 100 grados Celsius es igual a 212 grados Fahrenheit

# %%
#EXPORTACION DE MODELO A FORMATO H5
modelo.save('Red_Neuronal_1.h5')

# %%
# !ls
# Out:
# Red_Neuronal_1.h5  sample_data

# %%
#INSTALACION DE TENSORFLOW.JS
# !pip install tensorflowjs
# Out:
# ...
#      |████████████████████████████████| 77 kB 5.1 MB/s
# ...

# %%
#CARPETA DE CONVERSION
# !mkdir carpeta_salida

# %%
# !tensorflowjs_converter --input_format keras Red_Neuronal_1.h5 carpeta_salida

# %%
# !ls carpeta_salida
# Out:
# group1-shard1of1.bin  model.json
